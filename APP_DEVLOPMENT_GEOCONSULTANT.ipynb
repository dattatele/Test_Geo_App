# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns
import geoplot as glt
import geopandas as gpd

# %%
# %matplotlib inline

# %%
consultant_df = pd.read_excel('consultantloc.xlsx',null = 'NA')

# %%
consultant_df.head()
# Out:
#           FirstName   LastName EnrollmentDate  PSQV  L1L2QV  L1L6QV  ECLegs  \
# 0  Katelyn and Erik     Morgan     2013-11-26  3267   25561  180344      13
# 1            Andrea    Eriksen     2015-07-28   115     192     192       0
# 2            Ashley       Owen     2015-03-15  4040    7154    7449       4
# 3            Bailey  Klentzman     2015-10-12   273     273     273       0
# 4              Barb  Albritton     2015-12-02   939    2240    2240       1
#
#    LVECLegs         City State  PostalCode CountryCode          Address  \
# 0         1     Beaumont    TX  77706-2740         USA     Beaumont, TX
# 1         0   Northville    NY  12134-4307         USA   Northville, NY
# 2         0   Fort Worth    TX  76179-2849         USA   Fort Worth, TX
# 3         0      Cypress    TX  77429-4852         USA      Cypress, TX
# 4         0  Friendswood    TX  77546-6036         USA  Friendswood, TX
#
#     latitude  longitude
# 0  30.080174 -94.126556
# 1  43.225627 -74.172077
# ...

# %%
consultant_df['combine'] = consultant_df['FirstName'] + " " + consultant_df['LastName']

# %%
consultant_df['combine'].head()
# Out:
# 0    Katelyn and Erik Morgan
# 1             Andrea Eriksen
# 2                Ashley Owen
# 3           Bailey Klentzman
# 4             Barb Albritton
# Name: combine, dtype: object

# %%
list_name = (consultant_df['combine'])

# %%
consult_loc_df = consultant_df[['latitude', 'longitude']]
cons_location= [tuple(x) for x in consult_loc_df.values]
clear_tuple = (cons_location)
(clear_tuple)
# Out:
# [(30.080174, -94.126556199999996),
#  (43.2256274, -74.172076799999999),
#  (32.755488300000003, -97.330765799999995),
#  (29.971690500000001, -95.693785599999998),
#  (29.5293998, -95.201044699999997),
#  (30.4249276, -95.479941799999906),
#  (30.079940499999999, -95.417160099999904),
#  (30.097162099999998, -95.616054899999995),
#  (32.153215600000003, -94.799380200000002),
#  (32.153215600000003, -94.799380200000002),
#  (30.711029, -94.932989800000001),
#  (30.7235263, -95.550777099999905),
#  (30.7235263, -95.550777099999905),
#  (31.997345599999999, -102.0779146),
#  (32.1595947, -97.150007399999893),
#  (30.079940499999999, -95.417160099999904),
#  (30.079940499999999, -95.417160099999904),
#  (29.9913244, -93.958506700000001),
#  (30.080174, -94.126556199999996),
#  (30.080174, -94.126556199999996),
#  (32.755488300000003, -97.330765799999995),
#  (30.1316001, -94.015454099999999),
#  (30.7235263, -95.550777099999905),
#  (29.998831199999898, -95.262155299999904),
# ...

# %%
import gmaps
gmaps.configure(api_key="AIzaSyC2kLUzqlv6YkE2L0LcjSkzbxFMXoP6698")


locations = [locations for locations in clear_tuple]
names = [name for name in list_name]


info_html = [info for info in names]


fig = gmaps.figure()
symbol_layer = gmaps.symbol_layer(locations,hover_text=names,info_box_content=info_html)
fig.add_layer(symbol_layer)
fig
